# %%
import time
import csv
import pandas as pd
import numpy as np
import math
import subprocess
import os
import datetime
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
start = time.time() 
questions = pd.read_table('/Volumes/Untitled/データ解析コンペ/questions.tsv') 
print("読み込み時間：",time.time() - start)
# Out:
# 読み込み時間： 57.568098068237305

# %%
# questions_words = questions[['id', 'user_id', 'content']] 
questions_words = questions[['id', 'content']]

# %%
# 表示行数制限 撤廃
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option("display.max_colwidth", None)

# %%
len(questions_words)
# Out:
# 5451586

# %%
BASE = 20000
display = 1000

# %%
questions_words[BASE:BASE+display]
# Out:
#             id  \
# 20000  6466060
# 20001  6466061
# 20002  6466062
# 20003  6466063
# 20004  6466065
# 20005  6466066
# 20006  6466067
# 20007  6466068
# 20008  6466069
# 20009  6466072
# 20010  6466074
# 20011  6466076
# 20012  6466077
# 20013  6466078
# 20014  6466079
# 20015  6466080
# 20016  6466081
# 20017  6466082
# 20018  6466083
# 20019  6466084
# 20020  6466085
# 20021  6466086
# 20022  6466087
# 20023  6466088
# 20024  6466089
# 20025  6466091
# 20026  6466092
# 20027  6466093
# 20028  6466094
# 20029  6466095
# 20030  6466096
# 20031  6466097
# 20032  6466098
# 20033  6466099
# 20034  6466100
# 20035  6466101
# 20036  6466102
# 20037  6466103
# 20038  6466104
# 20039  6466105
# 20040  6466106
# 20041  6466108
# 20042  6466109
# 20043  6466110
# 20044  6466111
# 20045  6466113
# 20046  6466114
# 20047  6466115
# 20048  6466118
# 20049  6466119
# 20050  6466120
# 20051  6466121
# 20052  6466122
# 20053  6466123
# 20054  6466124
# 20055  6466125
# 20056  6466126
# ...

# %%
questions_words[BASE]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/envs/dca-3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10000
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
